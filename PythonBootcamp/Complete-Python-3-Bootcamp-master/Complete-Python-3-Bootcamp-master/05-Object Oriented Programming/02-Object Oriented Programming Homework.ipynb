# %% [markdown]
# # Object Oriented Programming
# ## Homework Assignment
#
# #### Problem 1
# Fill in the Line class methods to accept coordinates as a pair of tuples and return the slope and distance of the line.

# %%
class Line:
    
    def __init__(self,coor1,coor2):
        self.coor1 = coor1
        self.coor2 = coor2
        
    def distance(self):
        return (((self.coor2[1] - self.coor1[1]) ** 2) + ((self.coor2[0] - self.coor1[0]) ** 2)) ** (1/2)
    
    def slope(self):
        return (self.coor2[1] - self.coor1[1]) / (self.coor2[0] - self.coor1[0])

# %%
# EXAMPLE OUTPUT

coordinate1 = (3,2)
coordinate2 = (8,10)

li = Line(coordinate1,coordinate2)

# %%
li.distance()
# Out:
# 9.433981132056603

# %%
li.slope()
# Out:
# 1.6

# %% [markdown]
# ________
# #### Problem 2

# %% [markdown]
# Fill in the class

# %%
class Cylinder:
    
    pi = 3.14159265359
    
    def __init__(self,height=1,radius=1):
        self.height = height
        self.radius = radius
        
    def volume(self):
        return (self.height * (Cylinder.pi * (self.radius ** 2)))
    
    def surface_area(self):
        return (Cylinder.pi * (self.radius ** 2) * 2 + (self.height * 2 * Cylinder.pi * self.radius))

# %%
# EXAMPLE OUTPUT
c = Cylinder(2,3)

# %%
c.volume()
# Out:
# 56.54866776462

# %%
c.surface_area()
# Out:
# 94.24777960770001
